# %% [markdown]
# <a href="https://colab.research.google.com/github/WillKWL/Project-NBAGames/blob/master/source/1A_Games_load_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Does performance in pre-all star season predict playoff ranking?
# - Supervised offline binary classification task with imbalanced data
# - Performance measure: average precision (AUPRC)
# - Data source: https://www.nba.com/stats/teams/traditional/?sort=W&dir=-1&Season=2021-22&SeasonType=Regular%20Season
# - By predicting the probability of winning the championship based on mid-season (defined as regular season pre all-star game) performance of the NBA teams performance in the regular season before the All-Star game,
#   - As fans, we can tell whether our favorite team has a high chance to win this year during the middle of the season
#   - As coaching staff and team manager, we can tell if we need to make a change in our roster to increase our chances

# %%
# !pip install nba_api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nba_api
#   Downloading nba_api-1.1.11.tar.gz (125 kB)
#      |████████████████████████████████| 125 kB 5.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from nba_api) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->nba_api) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->nba_api) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->nba_api) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->nba_api) (3.0.4)
# Building wheels for collected packages: nba-api
#   Building wheel for nba-api (setup.py) ... done
#   Created wheel for nba-api: filename=nba_api-1.1.11-py3-none-any.whl size=251504 sha256=cb2875d4226d9b3f5fd5f737ef8a79a8af490eb61b3f913617e923cdf1a25a37
#   Stored in directory: /root/.cache/pip/wheels/e3/f4/46/996128675381abc175e306642bae575d372dcf7efc4683e551
# Successfully built nba-api
# Installing collected packages: nba-api
# Successfully installed nba-api-1.1.11

# %%
import pandas as pd
from nba_api.stats.endpoints import leaguedashteamstats, leaguedashplayerstats, leaguegamelog
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)
import os
from tqdm import tqdm
import numpy as np
from zlib import crc32
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [20, 5]
import re
import copy

# %% [markdown]
# # Gather data with [nba api](https://github.com/swar/nba_api)
# - stats adjusted per 100 posessions, instead of per game, to account for the different pace each team plays at
# - [glossary](https://www.nba.com/stats/help/glossary/) for column names
# - extra data: [advanced team stats](https://www.nba.com/stats/teams/advanced/?sort=W&dir=-1)

# %%
per_mode = 'Per100Possessions'

def get_team_table(measure_type, season, season_type, season_segment=""):
  # documentation: https://github.com/swar/nba_api/blob/master/docs/nba_api/stats/endpoints/leaguedashteamstats.md
  return leaguedashteamstats.LeagueDashTeamStats(
      per_mode_detailed=per_mode, 
      measure_type_detailed_defense=measure_type,
      season=season, 
      season_type_all_star=season_type,
      season_segment_nullable=season_segment).get_data_frames()[0]

def get_boxscore_table(season, season_type):
  # documentation: https://github.com/swar/nba_api/blob/master/docs/nba_api/stats/endpoints/leaguegamelog.md
  return leaguegamelog.LeagueGameLog(
      season=season, 
      season_type_all_star=season_type,
      player_or_team_abbreviation='T').get_data_frames()[0]

# %%
# season = '2021-22'
# boxscore_df = get_boxscore_table(season, "Playoffs")
# boxscore_df['HOME'] = boxscore_df['MATCHUP'].apply(lambda x: 0 if '@' in x else 1)
# boxscore_df['OUTCOME'] = np.where(boxscore_df['PLUS_MINUS'] > 0, 1, 0)
# playoff_teams = boxscore_df[['TEAM_ID', 'GAME_ID', 'OUTCOME']].groupby("GAME_ID").TEAM_ID.unique().reset_index()
# playoff_teams[['TEAM_ID', 'TEAM_ID_OPP']] = pd.DataFrame(playoff_teams['TEAM_ID'].tolist())
# playoff_teams2 = copy.deepcopy(playoff_teams)
# playoff_teams2[['TEAM_ID_OPP', 'TEAM_ID']] = playoff_teams2[['TEAM_ID', 'TEAM_ID_OPP']]
# playoff_games = pd.concat([playoff_teams, playoff_teams2]).sort_values("GAME_ID").merge(boxscore_df[['TEAM_ID', 'HOME', 'GAME_ID', 'OUTCOME']], on = ['GAME_ID', 'TEAM_ID'])
# playoff_games['SEASON'] = season
# playoff_games

# %%
# season_df = get_team_table("Base", season, "Regular Season", "Pre All-Star")
# season_df

# %%
# playoff_games.merge(season_df, on='TEAM_ID').merge(season_df, left_on='TEAM_ID_OPP', right_on='TEAM_ID', suffixes = ("", "_OPP"))

# %%
# season_df = get_team_table("Base", season, "Regular Season", "Pre All-Star")
# list_of_measures = ["Advanced", "Misc", "Four Factors", "Scoring", "Opponent", "Defense"]
# for measure in list_of_measures:
#   try:
#     print(measure)
#     print(get_team_table(measure, season, "Regular Season", "Pre All-Star").columns.values)
#   except:
#     print(f"error at {measure}")

# %%
def season_vs_playoff(start_year, end_year):
  output = None
  season_list = [str(i) + '-' + str(i+1)[2:] for i in range(start_year, end_year)]
  with tqdm(total=len(season_list)) as pbar:
    for season in season_list:
       
      # df for team stats
      try:
        team_df = get_team_table("Base", season, "Regular Season", "Pre All-Star")
      except:
        print(f"error at Base {season} team")
      list_of_measures = ["Advanced", "Misc", "Four Factors", "Scoring", "Opponent", "Defense"]
      for measure in list_of_measures:
        try:
          result_df = get_team_table(measure, season, "Regular Season", "Pre All-Star")
          # print(f"{measure} success")
          team_df = team_df.merge(
            result_df[['TEAM_ID'] + result_df.columns.difference(team_df.columns).tolist()], # only keep the unique columns + TEAM_ID
            on = "TEAM_ID", how = "inner", suffixes = ("", "_y"))
        except: 
          print(f"error at {measure} {season} team")

      remaining_col = [x for x in team_df.columns if 
                      (re.search('_RANK$', x) is None) &   # remove columns ending in _RANK as we will clean our features later
                      (re.search('^E_\w+', x) is None)     # remove columns starting with E_ (unknown estimates provided by NBA)
                      ]
      try:
        team_df = team_df[remaining_col]
      except:
        print(f"error at team {season}")

      season_df = copy.deepcopy(team_df)

      try:
        # get winning and losing team in playoff games
        boxscore_df = get_boxscore_table(season, "Playoffs")
        # 1 = home, 0 = away
        boxscore_df['HOME'] = boxscore_df['MATCHUP'].apply(lambda x: 0 if '@' in x else 1)
        # 1 = win, 0 = loss
        boxscore_df['OUTCOME'] = np.where(boxscore_df['PLUS_MINUS'] > 0, 1, 0)
        playoff_teams = boxscore_df[['TEAM_ID', 'GAME_ID', 'OUTCOME']].groupby("GAME_ID").TEAM_ID.unique().reset_index()
        # get TEAM_ID and opponent_ID
        playoff_teams[['TEAM_ID', 'TEAM_ID_OPP']] = pd.DataFrame(playoff_teams['TEAM_ID'].tolist())
        playoff_teams2 = copy.deepcopy(playoff_teams)
        playoff_teams2[['TEAM_ID_OPP', 'TEAM_ID']] = playoff_teams2[['TEAM_ID', 'TEAM_ID_OPP']]
        playoff_games = pd.concat([playoff_teams, playoff_teams2]).sort_values("GAME_ID").merge(boxscore_df[['TEAM_ID', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'OUTCOME', 'HOME']], on = ['GAME_ID', 'TEAM_ID'])
        # merge to get team stats and opponent stats
        playoff_games['SEASON'] = season
        final_df = playoff_games.merge(season_df, on='TEAM_ID').merge(season_df, left_on='TEAM_ID_OPP', right_on='TEAM_ID', suffixes = ("", "_OPP"))
        
        # clean columns
        final_df = final_df[[x for x in final_df.columns if re.search('\w+\.\w+', x) is None]]

        output = pd.concat([output,final_df], axis = 0)
      except Exception as e:
        print(f"error at {season} playoff, {e}")

      pbar.update(1)
  
  return output

# %%
df = season_vs_playoff(start_year = 1996, end_year = 2022)
df
# Out:
# 100%|██████████| 26/26 [02:00<00:00,  4.62s/it]
#         GAME_ID     TEAM_ID  TEAM_ID_OPP   GAME_DATE      MATCHUP  OUTCOME  \
# 0    0049600001  1610612766   1610612752  1997-04-24    CHH @ NYK        0
# 1    0049600010  1610612766   1610612752  1997-04-26    CHH @ NYK        0
# 2    0049600017  1610612766   1610612752  1997-04-28  CHH vs. NYK        0
# 3    0049600045  1610612748   1610612752  1997-05-07  MIA vs. NYK        0
# 4    0049600049  1610612748   1610612752  1997-05-09  MIA vs. NYK        1
# ..          ...         ...          ...         ...          ...      ...
# 169  0042100172  1610612742   1610612762  2022-04-18  DAL vs. UTA        1
# 170  0042100173  1610612742   1610612762  2022-04-21    DAL @ UTA        1
# 171  0042100174  1610612742   1610612762  2022-04-23    DAL @ UTA        0
# 172  0042100175  1610612742   1610612762  2022-04-25  DAL vs. UTA        1
# 173  0042100176  1610612742   1610612762  2022-04-28    DAL @ UTA        1
#
#      HOME   SEASON          TEAM_NAME  GP   W   L  W_PCT   MIN   FGM   FGA  \
# 0       0  1996-97  Charlotte Hornets  48  29  19  0.604  53.4  39.3  85.6
# 1       0  1996-97  Charlotte Hornets  48  29  19  0.604  53.4  39.3  85.6
# 2       1  1996-97  Charlotte Hornets  48  29  19  0.604  53.4  39.3  85.6
# 3       1  1996-97         Miami Heat  48  36  12  0.750  53.7  37.6  83.6
# 4       1  1996-97         Miami Heat  48  36  12  0.750  53.7  37.6  83.6
# ..    ...      ...                ...  ..  ..  ..    ...   ...   ...   ...
# 169     1  2021-22   Dallas Mavericks  59  35  24  0.593  50.1  40.6  89.2
# 170     0  2021-22   Dallas Mavericks  59  35  24  0.593  50.1  40.6  89.2
# 171     0  2021-22   Dallas Mavericks  59  35  24  0.593  50.1  40.6  89.2
# 172     1  2021-22   Dallas Mavericks  59  35  24  0.593  50.1  40.6  89.2
# 173     0  2021-22   Dallas Mavericks  59  35  24  0.593  50.1  40.6  89.2
#
#      FG_PCT  FG3M  FG3A  FG3_PCT   FTM   FTA  FT_PCT  OREB  DREB   REB   AST  \
# 0     0.459   7.7  18.2    0.424  20.4  26.7   0.763  12.4  31.0  43.4  26.4
# 1     0.459   7.7  18.2    0.424  20.4  26.7   0.763  12.4  31.0  43.4  26.4
# 2     0.459   7.7  18.2    0.424  20.4  26.7   0.763  12.4  31.0  43.4  26.4
# 171    0.529         3.6       110.8     0.258  95.81       79.84  0.512
# 172    0.529         3.6       110.8     0.258  95.81       79.84  0.512
# 173    0.529         3.6       110.8     0.258  95.81       79.84  0.512
#
#      POSS  REB_PCT  TM_TOV_PCT  TS_PCT  OPP_PTS_2ND_CHANCE  OPP_PTS_FB  \
# 0    4333    0.493       0.164   0.548                17.1        12.3
# 1    4333    0.493       0.164   0.548                17.1        12.3
# 2    4333    0.493       0.164   0.548                17.1        12.3
# 3    4322    0.508       0.183   0.540                14.0         9.9
# 4    4322    0.508       0.183   0.540                14.0         9.9
# ..    ...      ...         ...     ...                 ...         ...
# 169  5679    0.497       0.130   0.561                13.7        12.5
# 170  5679    0.497       0.130   0.561                13.7        12.5
# 171  5679    0.497       0.130   0.561                13.7        12.5
# 172  5679    0.497       0.130   0.561                13.7        12.5
# 173  5679    0.497       0.130   0.561                13.7        12.5
#
#      OPP_PTS_OFF_TOV  OPP_PTS_PAINT  PTS_2ND_CHANCE  PTS_FB  PTS_OFF_TOV  \
# 0               18.3           45.6            13.5    11.2         18.1
# 1               18.3           45.6            13.5    11.2         18.1
# 2               18.3           45.6            13.5    11.2         18.1
# 3               19.4           40.6            15.1    12.7         20.3
# 4               19.4           40.6            15.1    12.7         20.3
# ..               ...            ...             ...     ...          ...
# 169             14.9           48.8            11.0    10.4         15.8
# 170             14.9           48.8            11.0    10.4         15.8
# 171             14.9           48.8            11.0    10.4         15.8
# 172             14.9           48.8            11.0    10.4         15.8
# 173             14.9           48.8            11.0    10.4         15.8
#
#      PTS_PAINT  FTA_RATE  OPP_EFG_PCT  OPP_FTA_RATE  OPP_OREB_PCT  \
# 0         40.3     0.312        0.496         0.275         0.338
# 1         40.3     0.312        0.496         0.275         0.338
# 2         40.3     0.312        0.496         0.275         0.338
# 3         41.3     0.332        0.455         0.334         0.321
# 4         41.3     0.332        0.455         0.334         0.321
# ..         ...       ...          ...           ...           ...
# 169       43.9     0.241        0.517         0.237         0.264
# 170       43.9     0.241        0.517         0.237         0.264
# 171       43.9     0.241        0.517         0.237         0.264
# 172       43.9     0.241        0.517         0.237         0.264
# 173       43.9     0.241        0.517         0.237         0.264
#
#      OPP_TOV_PCT  PCT_AST_2PM  PCT_AST_3PM  PCT_AST_FGM  PCT_FGA_2PT  \
# 0          0.154        0.630        0.853        0.674        0.788
# 1          0.154        0.630        0.853        0.674        0.788
# 2          0.154        0.630        0.853        0.674        0.788
# 3          0.180        0.544        0.804        0.603        0.714
# 4          0.180        0.544        0.804        0.603        0.714
# ..           ...          ...          ...          ...          ...
# 169        0.141        0.513        0.802        0.607        0.570
# 170        0.141        0.513        0.802        0.607        0.570
# 171        0.141        0.513        0.802        0.607        0.570
# 172        0.141        0.513        0.802        0.607        0.570
# 173        0.141        0.513        0.802        0.607        0.570
#
#      PCT_FGA_3PT  PCT_PTS_2PT  PCT_PTS_2PT_MR  PCT_PTS_3PT  PCT_PTS_FB  \
# 0          0.212        0.592           0.214        0.217       0.105
# 1          0.212        0.592           0.214        0.217       0.105
# 2          0.212        0.592           0.214        0.217       0.105
# 3          0.286        0.559           0.161        0.250       0.123
# 4          0.286        0.559           0.161        0.250       0.123
# ..           ...          ...             ...          ...         ...
# 169        0.430        0.495           0.099        0.357       0.094
# 170        0.430        0.495           0.099        0.357       0.094
# 171        0.430        0.495           0.099        0.357       0.094
# 172        0.430        0.495           0.099        0.357       0.094
# 173        0.430        0.495           0.099        0.357       0.094
#
#      PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  PCT_UAST_2PM  PCT_UAST_3PM  \
# 0         0.191            0.170          0.378         0.370         0.147
# 1         0.191            0.170          0.378         0.370         0.147
# 2         0.191            0.170          0.378         0.370         0.147
# 3         0.190            0.196          0.399         0.456         0.196
# 4         0.190            0.196          0.399         0.456         0.196
# ..          ...              ...            ...           ...           ...
# 169       0.148            0.143          0.396         0.487         0.198
# 170       0.148            0.143          0.396         0.487         0.198
# 171       0.148            0.143          0.396         0.487         0.198
# 172       0.148            0.143          0.396         0.487         0.198
# 173       0.148            0.143          0.396         0.487         0.198
#
#      PCT_UAST_FGM  OPP_AST  OPP_BLK  OPP_BLKA  OPP_DREB  OPP_FG3A  OPP_FG3M  \
# 0           0.326     23.7      5.1       4.4      31.3      18.5       6.8
# 1           0.326     23.7      5.1       4.4      31.3      18.5       6.8
# 2           0.326     23.7      5.1       4.4      31.3      18.5       6.8
# 3           0.397     20.3      5.4       6.5      31.3      15.1       5.5
# 4           0.397     20.3      5.4       6.5      31.3      15.1       5.5
# ..            ...      ...      ...       ...       ...       ...       ...
# 169         0.393     24.2      3.9       4.2      36.2      32.9      11.0
# 170         0.393     24.2      3.9       4.2      36.2      32.9      11.0
# 171         0.393     24.2      3.9       4.2      36.2      32.9      11.0
# 172         0.393     24.2      3.9       4.2      36.2      32.9      11.0
# 173         0.393     24.2      3.9       4.2      36.2      32.9      11.0
#
#      OPP_FG3_PCT  OPP_FGA  OPP_FGM  OPP_FG_PCT  OPP_FTA  OPP_FTM  OPP_FT_PCT  \
# 0          0.368     89.6     41.0       0.458     24.7     17.8       0.723
# 1          0.368     89.6     41.0       0.458     24.7     17.8       0.723
# 2          0.368     89.6     41.0       0.458     24.7     17.8       0.723
# 3          0.361     84.5     35.7       0.423     28.2     21.0       0.745
# 4          0.361     84.5     35.7       0.423     28.2     21.0       0.745
# ..           ...      ...      ...         ...      ...      ...         ...
# 169        0.335     88.5     40.2       0.455     21.0     15.8       0.755
# 170        0.335     88.5     40.2       0.455     21.0     15.8       0.755
# 171        0.335     88.5     40.2       0.455     21.0     15.8       0.755
# 172        0.335     88.5     40.2       0.455     21.0     15.8       0.755
# 173        0.335     88.5     40.2       0.455     21.0     15.8       0.755
#
#      OPP_OREB  OPP_PF  OPP_PFD  OPP_PTS  OPP_REB  OPP_STL  OPP_TOV  \
# 0        14.3    24.3     23.6    106.7     45.6      7.2     15.4
# 1        14.3    24.3     23.6    106.7     45.6      7.2     15.4
# 2        14.3    24.3     23.6    106.7     45.6      7.2     15.4
# 3        13.6    25.5     26.1     97.9     44.9      9.0     18.0
# 4        13.6    25.5     26.1     97.9     44.9      9.0     18.0
# ..        ...     ...      ...      ...      ...      ...      ...
# 169       9.8    20.8     20.6    107.3     45.9      7.0     14.1
# 170       9.8    20.8     20.6    107.3     45.9      7.0     14.1
# 171       9.8    20.8     20.6    107.3     45.9      7.0     14.1
# 172       9.8    20.8     20.6    107.3     45.9      7.0     14.1
# 173       9.8    20.8     20.6    107.3     45.9      7.0     14.1
#
#      TEAM_ID_OPP    TEAM_NAME_OPP  GP_OPP  W_OPP  L_OPP  W_PCT_OPP  MIN_OPP  \
# 0     1610612752  New York Knicks      48     34     14      0.708     52.0
# 1     1610612752  New York Knicks      48     34     14      0.708     52.0
# 2     1610612752  New York Knicks      48     34     14      0.708     52.0
# 3     1610612752  New York Knicks      48     34     14      0.708     52.0
# 4     1610612752  New York Knicks      48     34     14      0.708     52.0
# ..           ...              ...     ...    ...    ...        ...      ...
# 169   1610612762        Utah Jazz      58     36     22      0.621     48.9
# 170   1610612762        Utah Jazz      58     36     22      0.621     48.9
# 171   1610612762        Utah Jazz      58     36     22      0.621     48.9
# 172   1610612762        Utah Jazz      58     36     22      0.621     48.9
# 173   1610612762        Utah Jazz      58     36     22      0.621     48.9
#
#      FGM_OPP  FGA_OPP  FG_PCT_OPP  FG3M_OPP  FG3A_OPP  FG3_PCT_OPP  FTM_OPP  \
# 0       38.1     82.9       0.459       6.2      17.0        0.368     19.7
# 1       38.1     82.9       0.459       6.2      17.0        0.368     19.7
# 2       38.1     82.9       0.459       6.2      17.0        0.368     19.7
# 3       38.1     82.9       0.459       6.2      17.0        0.368     19.7
# 4       38.1     82.9       0.459       6.2      17.0        0.368     19.7
# ..       ...      ...         ...       ...       ...          ...      ...
# 169     41.4     87.6       0.473      14.8      41.0        0.361     18.2
# 170     41.4     87.6       0.473      14.8      41.0        0.361     18.2
# 171     41.4     87.6       0.473      14.8      41.0        0.361     18.2
# 172     41.4     87.6       0.473      14.8      41.0        0.361     18.2
# 173     41.4     87.6       0.473      14.8      41.0        0.361     18.2
#
#      FTA_OPP  FT_PCT_OPP  OREB_OPP  DREB_OPP  REB_OPP  AST_OPP  TOV_OPP  \
# 0       26.3       0.750      13.5      32.7     46.3     23.7     20.0
# 1       26.3       0.750      13.5      32.7     46.3     23.7     20.0
# 2       26.3       0.750      13.5      32.7     46.3     23.7     20.0
# 3       26.3       0.750      13.5      32.7     46.3     23.7     20.0
# 4       26.3       0.750      13.5      32.7     46.3     23.7     20.0
# ..       ...         ...       ...       ...      ...      ...      ...
# 169     23.2       0.783      10.4      36.5     46.9     22.7     14.5
# 170     23.2       0.783      10.4      36.5     46.9     22.7     14.5
# 171     23.2       0.783      10.4      36.5     46.9     22.7     14.5
# 172     23.2       0.783      10.4      36.5     46.9     22.7     14.5
# 173     23.2       0.783      10.4      36.5     46.9     22.7     14.5
#
#      STL_OPP  BLK_OPP  BLKA_OPP  PF_OPP  PFD_OPP  PTS_OPP  PLUS_MINUS_OPP  \
# 0        8.7      5.4       3.9    26.9      0.1    102.1             3.8
# 1        8.7      5.4       3.9    26.9      0.1    102.1             3.8
# 2        8.7      5.4       3.9    26.9      0.1    102.1             3.8
# 3        8.7      5.4       3.9    26.9      0.1    102.1             3.8
# 4        8.7      5.4       3.9    26.9      0.1    102.1             3.8
# ..       ...      ...       ...     ...      ...      ...             ...
# 169      7.3      5.0       4.3    19.3     20.4    115.9             7.0
# 170      7.3      5.0       4.3    19.3     20.4    115.9             7.0
# 171      7.3      5.0       4.3    19.3     20.4    115.9             7.0
# 172      7.3      5.0       4.3    19.3     20.4    115.9             7.0
# 173      7.3      5.0       4.3    19.3     20.4    115.9             7.0
#
#      CFID_OPP     CFPARAMS_OPP  AST_PCT_OPP  AST_RATIO_OPP  AST_TO_OPP  \
# 0          10  New York Knicks        0.622           17.0        1.18
# 1          10  New York Knicks        0.622           17.0        1.18
# 2          10  New York Knicks        0.622           17.0        1.18
# 3          10  New York Knicks        0.622           17.0        1.18
# 4          10  New York Knicks        0.622           17.0        1.18
# ..        ...              ...          ...            ...         ...
# 169        10        Utah Jazz        0.549           16.7        1.57
# 170        10        Utah Jazz        0.549           16.7        1.57
# 171        10        Utah Jazz        0.549           16.7        1.57
# 172        10        Utah Jazz        0.549           16.7        1.57
# 173        10        Utah Jazz        0.549           16.7        1.57
#
#      DEF_RATING_OPP  DREB_PCT_OPP  EFG_PCT_OPP  NET_RATING_OPP  \
# 0              98.2         0.697        0.497             3.9
# 1              98.2         0.697        0.497             3.9
# 2              98.2         0.697        0.497             3.9
# 3              98.2         0.697        0.497             3.9
# 4              98.2         0.697        0.497             3.9
# ..              ...           ...          ...             ...
# 169           109.0         0.736        0.557             6.9
# 170           109.0         0.736        0.557             6.9
# 171           109.0         0.736        0.557             6.9
# 172           109.0         0.736        0.557             6.9
# 173           109.0         0.736        0.557             6.9
#
#      OFF_RATING_OPP  OREB_PCT_OPP  PACE_OPP  PACE_PER40_OPP  PIE_OPP  \
# 0             102.1         0.335     92.40           77.00    0.536
# 1             102.1         0.335     92.40           77.00    0.536
# 2             102.1         0.335     92.40           77.00    0.536
# 3             102.1         0.335     92.40           77.00    0.536
# 4             102.1         0.335     92.40           77.00    0.536
# ..              ...           ...       ...             ...      ...
# 169           115.9         0.290     98.12           81.77    0.534
# 170           115.9         0.290     98.12           81.77    0.534
# 171           115.9         0.290     98.12           81.77    0.534
# 172           115.9         0.290     98.12           81.77    0.534
# 173           115.9         0.290     98.12           81.77    0.534
#
#      POSS_OPP  REB_PCT_OPP  TM_TOV_PCT_OPP  TS_PCT_OPP  \
# 0        4452        0.520           0.200       0.541
# 1        4452        0.520           0.200       0.541
# 2        4452        0.520           0.200       0.541
# 3        4452        0.520           0.200       0.541
# 4        4452        0.520           0.200       0.541
# ..        ...          ...             ...         ...
# 169      5694        0.522           0.145       0.592
# 170      5694        0.522           0.145       0.592
# 171      5694        0.522           0.145       0.592
# 172      5694        0.522           0.145       0.592
# 173      5694        0.522           0.145       0.592
#
#      OPP_PTS_2ND_CHANCE_OPP  OPP_PTS_FB_OPP  OPP_PTS_OFF_TOV_OPP  \
# 0                      13.6             8.7                 20.4
# 1                      13.6             8.7                 20.4
# 2                      13.6             8.7                 20.4
# 3                      13.6             8.7                 20.4
# 4                      13.6             8.7                 20.4
# ..                      ...             ...                  ...
# 169                    13.1            12.2                 17.0
# 170                    13.1            12.2                 17.0
# 171                    13.1            12.2                 17.0
# 172                    13.1            12.2                 17.0
# 173                    13.1            12.2                 17.0
#
#      OPP_PTS_PAINT_OPP  PTS_2ND_CHANCE_OPP  PTS_FB_OPP  PTS_OFF_TOV_OPP  \
# 0                 35.3                15.3        12.6             20.7
# 1                 35.3                15.3        12.6             20.7
# 2                 35.3                15.3        12.6             20.7
# 3                 35.3                15.3        12.6             20.7
# 4                 35.3                15.3        12.6             20.7
# ..                 ...                 ...         ...              ...
# 169               47.2                14.6        10.1             15.2
# 170               47.2                14.6        10.1             15.2
# 171               47.2                14.6        10.1             15.2
# 172               47.2                14.6        10.1             15.2
# 173               47.2                14.6        10.1             15.2
#
#      PTS_PAINT_OPP  FTA_RATE_OPP  OPP_EFG_PCT_OPP  OPP_FTA_RATE_OPP  \
# 0             42.3         0.318            0.466             0.389
# 1             42.3         0.318            0.466             0.389
# 2             42.3         0.318            0.466             0.389
# 3             42.3         0.318            0.466             0.389
# 4             42.3         0.318            0.466             0.389
# ..             ...           ...              ...               ...
# 169           49.1         0.265            0.516             0.209
# 170           49.1         0.265            0.516             0.209
# 171           49.1         0.265            0.516             0.209
# 172           49.1         0.265            0.516             0.209
# 173           49.1         0.265            0.516             0.209
#
#      OPP_OREB_PCT_OPP  OPP_TOV_PCT_OPP  PCT_AST_2PM_OPP  PCT_AST_3PM_OPP  \
# 0               0.303            0.190            0.593            0.773
# 1               0.303            0.190            0.593            0.773
# 2               0.303            0.190            0.593            0.773
# 3               0.303            0.190            0.593            0.773
# 4               0.303            0.190            0.593            0.773
# ..                ...              ...              ...              ...
# 169             0.264            0.124            0.452            0.722
# 170             0.264            0.124            0.452            0.722
# 171             0.264            0.124            0.452            0.722
# 172             0.264            0.124            0.452            0.722
# 173             0.264            0.124            0.452            0.722
#
#      PCT_AST_FGM_OPP  PCT_FGA_2PT_OPP  PCT_FGA_3PT_OPP  PCT_PTS_2PT_OPP  \
# 0              0.622            0.795            0.205            0.623
# 1              0.622            0.795            0.205            0.623
# 2              0.622            0.795            0.205            0.623
# 3              0.622            0.795            0.205            0.623
# 4              0.622            0.795            0.205            0.623
# ..               ...              ...              ...              ...
# 169            0.549            0.532            0.468            0.460
# 170            0.549            0.532            0.468            0.460
# 171            0.549            0.532            0.468            0.460
# 172            0.549            0.532            0.468            0.460
# 173            0.549            0.532            0.468            0.460
#
#      PCT_PTS_2PT_MR_OPP  PCT_PTS_3PT_OPP  PCT_PTS_FB_OPP  PCT_PTS_FT_OPP  \
# 0                 0.209            0.183           0.123           0.193
# 1                 0.209            0.183           0.123           0.193
# 2                 0.209            0.183           0.123           0.193
# 3                 0.209            0.183           0.123           0.193
# 4                 0.209            0.183           0.123           0.193
# ..                  ...              ...             ...             ...
# 169               0.036            0.383           0.087           0.157
# 170               0.036            0.383           0.087           0.157
# 171               0.036            0.383           0.087           0.157
# 172               0.036            0.383           0.087           0.157
# 173               0.036            0.383           0.087           0.157
#
#      PCT_PTS_OFF_TOV_OPP  PCT_PTS_PAINT_OPP  PCT_UAST_2PM_OPP  \
# 0                  0.202              0.414             0.407
# 1                  0.202              0.414             0.407
# 2                  0.202              0.414             0.407
# 3                  0.202              0.414             0.407
# 4                  0.202              0.414             0.407
# ..                   ...                ...               ...
# 169                0.131              0.424             0.548
# 170                0.131              0.424             0.548
# 171                0.131              0.424             0.548
# 172                0.131              0.424             0.548
# 173                0.131              0.424             0.548
#
#      PCT_UAST_3PM_OPP  PCT_UAST_FGM_OPP  OPP_AST_OPP  OPP_BLK_OPP  \
# 0               0.227             0.378         20.9          3.9
# 1               0.227             0.378         20.9          3.9
# 2               0.227             0.378         20.9          3.9
# 3               0.227             0.378         20.9          3.9
# 4               0.227             0.378         20.9          3.9
# ..                ...               ...          ...          ...
# 169             0.278             0.451         23.5          4.3
# 170             0.278             0.451         23.5          4.3
# 171             0.278             0.451         23.5          4.3
# 172             0.278             0.451         23.5          4.3
# 173             0.278             0.451         23.5          4.3
#
#      OPP_BLKA_OPP  OPP_DREB_OPP  OPP_FG3A_OPP  OPP_FG3M_OPP  OPP_FG3_PCT_OPP  \
# 0             5.4          29.3          18.4           6.6            0.360
# 1             5.4          29.3          18.4           6.6            0.360
# 2             5.4          29.3          18.4           6.6            0.360
# 3             5.4          29.3          18.4           6.6            0.360
# 4             5.4          29.3          18.4           6.6            0.360
# ..            ...           ...           ...           ...              ...
# 169           5.0          32.5          35.0          12.0            0.342
# 170           5.0          32.5          35.0          12.0            0.342
# 171           5.0          32.5          35.0          12.0            0.342
# 172           5.0          32.5          35.0          12.0            0.342
# 173           5.0          32.5          35.0          12.0            0.342
#
#      OPP_FGA_OPP  OPP_FGM_OPP  OPP_FG_PCT_OPP  OPP_FTA_OPP  OPP_FTM_OPP  \
# 0           81.0         34.4           0.425         31.5         22.9
# 1           81.0         34.4           0.425         31.5         22.9
# 2           81.0         34.4           0.425         31.5         22.9
# 3           81.0         34.4           0.425         31.5         22.9
# 4           81.0         34.4           0.425         31.5         22.9
# ..           ...          ...             ...          ...          ...
# 169         91.7         41.3           0.450         19.2         14.3
# 170         91.7         41.3           0.450         19.2         14.3
# 171         91.7         41.3           0.450         19.2         14.3
# 172         91.7         41.3           0.450         19.2         14.3
# 173         91.7         41.3           0.450         19.2         14.3
#
#      OPP_FT_PCT_OPP  OPP_OREB_OPP  OPP_PF_OPP  OPP_PFD_OPP  OPP_PTS_OPP  \
# 0             0.726          11.7        24.2         26.9         98.3
# 1             0.726          11.7        24.2         26.9         98.3
# 2             0.726          11.7        24.2         26.9         98.3
# 3             0.726          11.7        24.2         26.9         98.3
# 4             0.726          11.7        24.2         26.9         98.3
# ..              ...           ...         ...          ...          ...
# 169           0.746          10.3        20.4         19.3        108.9
# 170           0.746          10.3        20.4         19.3        108.9
# 171           0.746          10.3        20.4         19.3        108.9
# 172           0.746          10.3        20.4         19.3        108.9
# 173           0.746          10.3        20.4         19.3        108.9
#
#      OPP_REB_OPP  OPP_STL_OPP  OPP_TOV_OPP
# 0           41.0          9.9         19.0
# 1           41.0          9.9         19.0
# 2           41.0          9.9         19.0
# 3           41.0          9.9         19.0
# 4           41.0          9.9         19.0
# ..           ...          ...          ...
# 169         42.8          7.7         12.4
# 170         42.8          7.7         12.4
# 171         42.8          7.7         12.4
# 172         42.8          7.7         12.4
# 173         42.8          7.7         12.4
#
# [4210 rows x 195 columns]

# %%
# df_2002 = season_vs_playoff(start_year = 2002, end_year = 2003)
# for team_id in df_2002.TEAM_ID.unique():
#   df.loc[(df.TEAM_ID == team_id) & (df.SEASON == '2002-03')] = df_2002.loc[(df_2002.TEAM_ID == team_id)]
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]

# %%
df.to_csv('nba_pre_all_star_vs_playoff_games.csv', index = False)
# download local copy to upload to github
from google.colab import files
files.download("nba_pre_all_star_vs_playoff_games.csv")

# %%
# pull from github
df = pd.read_csv('https://github.com/WillKWL/PublicData/raw/main/raw/nba_pre_all_star_vs_playoff_games.csv')
df
# Out:
#        GAME_ID     TEAM_ID  TEAM_ID_OPP   GAME_DATE      MATCHUP  OUTCOME  \
# 0     49600001  1610612766   1610612752  1997-04-24    CHH @ NYK        0
# 1     49600010  1610612766   1610612752  1997-04-26    CHH @ NYK        0
# 2     49600017  1610612766   1610612752  1997-04-28  CHH vs. NYK        0
# 3     49600045  1610612748   1610612752  1997-05-07  MIA vs. NYK        0
# 4     49600049  1610612748   1610612752  1997-05-09  MIA vs. NYK        1
# ...        ...         ...          ...         ...          ...      ...
# 4205  42100172  1610612742   1610612762  2022-04-18  DAL vs. UTA        1
# 4206  42100173  1610612742   1610612762  2022-04-21    DAL @ UTA        1
# 4207  42100174  1610612742   1610612762  2022-04-23    DAL @ UTA        0
# 4208  42100175  1610612742   1610612762  2022-04-25  DAL vs. UTA        1
# 4209  42100176  1610612742   1610612762  2022-04-28    DAL @ UTA        1
#
#       HOME   SEASON          TEAM_NAME  GP   W   L  W_PCT   MIN   FGM   FGA  \
# 0        0  1996-97  Charlotte Hornets  48  29  19  0.604  53.4  39.3  85.6
# 1        0  1996-97  Charlotte Hornets  48  29  19  0.604  53.4  39.3  85.6
# 2        1  1996-97  Charlotte Hornets  48  29  19  0.604  53.4  39.3  85.6
# 3        1  1996-97         Miami Heat  48  36  12  0.750  53.7  37.6  83.6
# 4        1  1996-97         Miami Heat  48  36  12  0.750  53.7  37.6  83.6
# ...    ...      ...                ...  ..  ..  ..    ...   ...   ...   ...
# 4205     1  2021-22   Dallas Mavericks  59  35  24  0.593  50.1  40.6  89.2
# 4206     0  2021-22   Dallas Mavericks  59  35  24  0.593  50.1  40.6  89.2
# 4207     0  2021-22   Dallas Mavericks  59  35  24  0.593  50.1  40.6  89.2
# 4208     1  2021-22   Dallas Mavericks  59  35  24  0.593  50.1  40.6  89.2
# 4209     0  2021-22   Dallas Mavericks  59  35  24  0.593  50.1  40.6  89.2
#
# 4208        0.335     88.5     40.2       0.455     21.0     15.8       0.755
# 4209        0.335     88.5     40.2       0.455     21.0     15.8       0.755
#
#       OPP_OREB  OPP_PF  OPP_PFD  OPP_PTS  OPP_REB  OPP_STL  OPP_TOV  \
# 0         14.3    24.3     23.6    106.7     45.6      7.2     15.4
# 1         14.3    24.3     23.6    106.7     45.6      7.2     15.4
# 2         14.3    24.3     23.6    106.7     45.6      7.2     15.4
# 3         13.6    25.5     26.1     97.9     44.9      9.0     18.0
# 4         13.6    25.5     26.1     97.9     44.9      9.0     18.0
# ...        ...     ...      ...      ...      ...      ...      ...
# 4205       9.8    20.8     20.6    107.3     45.9      7.0     14.1
# 4206       9.8    20.8     20.6    107.3     45.9      7.0     14.1
# 4207       9.8    20.8     20.6    107.3     45.9      7.0     14.1
# 4208       9.8    20.8     20.6    107.3     45.9      7.0     14.1
# 4209       9.8    20.8     20.6    107.3     45.9      7.0     14.1
#
#       TEAM_ID_OPP.1    TEAM_NAME_OPP  GP_OPP  W_OPP  L_OPP  W_PCT_OPP  \
# 0        1610612752  New York Knicks      48     34     14      0.708
# 1        1610612752  New York Knicks      48     34     14      0.708
# 2        1610612752  New York Knicks      48     34     14      0.708
# 3        1610612752  New York Knicks      48     34     14      0.708
# 4        1610612752  New York Knicks      48     34     14      0.708
# ...             ...              ...     ...    ...    ...        ...
# 4205     1610612762        Utah Jazz      58     36     22      0.621
# 4206     1610612762        Utah Jazz      58     36     22      0.621
# 4207     1610612762        Utah Jazz      58     36     22      0.621
# 4208     1610612762        Utah Jazz      58     36     22      0.621
# 4209     1610612762        Utah Jazz      58     36     22      0.621
#
#       MIN_OPP  FGM_OPP  FGA_OPP  FG_PCT_OPP  FG3M_OPP  FG3A_OPP  FG3_PCT_OPP  \
# 0        52.0     38.1     82.9       0.459       6.2      17.0        0.368
# 1        52.0     38.1     82.9       0.459       6.2      17.0        0.368
# 2        52.0     38.1     82.9       0.459       6.2      17.0        0.368
# 3        52.0     38.1     82.9       0.459       6.2      17.0        0.368
# 4        52.0     38.1     82.9       0.459       6.2      17.0        0.368
# ...       ...      ...      ...         ...       ...       ...          ...
# 4205     48.9     41.4     87.6       0.473      14.8      41.0        0.361
# 4206     48.9     41.4     87.6       0.473      14.8      41.0        0.361
# 4207     48.9     41.4     87.6       0.473      14.8      41.0        0.361
# 4208     48.9     41.4     87.6       0.473      14.8      41.0        0.361
# 4209     48.9     41.4     87.6       0.473      14.8      41.0        0.361
#
#       FTM_OPP  FTA_OPP  FT_PCT_OPP  OREB_OPP  DREB_OPP  REB_OPP  AST_OPP  \
# 0        19.7     26.3       0.750      13.5      32.7     46.3     23.7
# 1        19.7     26.3       0.750      13.5      32.7     46.3     23.7
# 2        19.7     26.3       0.750      13.5      32.7     46.3     23.7
# 3        19.7     26.3       0.750      13.5      32.7     46.3     23.7
# 4        19.7     26.3       0.750      13.5      32.7     46.3     23.7
# ...       ...      ...         ...       ...       ...      ...      ...
# 4205     18.2     23.2       0.783      10.4      36.5     46.9     22.7
# 4206     18.2     23.2       0.783      10.4      36.5     46.9     22.7
# 4207     18.2     23.2       0.783      10.4      36.5     46.9     22.7
# 4208     18.2     23.2       0.783      10.4      36.5     46.9     22.7
# 4209     18.2     23.2       0.783      10.4      36.5     46.9     22.7
#
#       TOV_OPP  STL_OPP  BLK_OPP  BLKA_OPP  PF_OPP  PFD_OPP  PTS_OPP  \
# 0        20.0      8.7      5.4       3.9    26.9      0.1    102.1
# 1        20.0      8.7      5.4       3.9    26.9      0.1    102.1
# 2        20.0      8.7      5.4       3.9    26.9      0.1    102.1
# 3        20.0      8.7      5.4       3.9    26.9      0.1    102.1
# 4        20.0      8.7      5.4       3.9    26.9      0.1    102.1
# ...       ...      ...      ...       ...     ...      ...      ...
# 4205     14.5      7.3      5.0       4.3    19.3     20.4    115.9
# 4206     14.5      7.3      5.0       4.3    19.3     20.4    115.9
# 4207     14.5      7.3      5.0       4.3    19.3     20.4    115.9
# 4208     14.5      7.3      5.0       4.3    19.3     20.4    115.9
# 4209     14.5      7.3      5.0       4.3    19.3     20.4    115.9
#
#       PLUS_MINUS_OPP  CFID_OPP     CFPARAMS_OPP  AST_PCT_OPP  AST_RATIO_OPP  \
# 0                3.8        10  New York Knicks        0.622           17.0
# 1                3.8        10  New York Knicks        0.622           17.0
# 2                3.8        10  New York Knicks        0.622           17.0
# 3                3.8        10  New York Knicks        0.622           17.0
# 4                3.8        10  New York Knicks        0.622           17.0
# ...              ...       ...              ...          ...            ...
# 4205             7.0        10        Utah Jazz        0.549           16.7
# 4206             7.0        10        Utah Jazz        0.549           16.7
# 4207             7.0        10        Utah Jazz        0.549           16.7
# 4208             7.0        10        Utah Jazz        0.549           16.7
# 4209             7.0        10        Utah Jazz        0.549           16.7
#
#       AST_TO_OPP  DEF_RATING_OPP  DREB_PCT_OPP  EFG_PCT_OPP  NET_RATING_OPP  \
# 0           1.18            98.2         0.697        0.497             3.9
# 1           1.18            98.2         0.697        0.497             3.9
# 2           1.18            98.2         0.697        0.497             3.9
# 3           1.18            98.2         0.697        0.497             3.9
# 4           1.18            98.2         0.697        0.497             3.9
# ...          ...             ...           ...          ...             ...
# 4205        1.57           109.0         0.736        0.557             6.9
# 4206        1.57           109.0         0.736        0.557             6.9
# 4207        1.57           109.0         0.736        0.557             6.9
# 4208        1.57           109.0         0.736        0.557             6.9
# 4209        1.57           109.0         0.736        0.557             6.9
#
#       OFF_RATING_OPP  OREB_PCT_OPP  PACE_OPP  PACE_PER40_OPP  PIE_OPP  \
# 0              102.1         0.335     92.40           77.00    0.536
# 1              102.1         0.335     92.40           77.00    0.536
# 2              102.1         0.335     92.40           77.00    0.536
# 3              102.1         0.335     92.40           77.00    0.536
# 4              102.1         0.335     92.40           77.00    0.536
# ...              ...           ...       ...             ...      ...
# 4205           115.9         0.290     98.12           81.77    0.534
# 4206           115.9         0.290     98.12           81.77    0.534
# 4207           115.9         0.290     98.12           81.77    0.534
# 4208           115.9         0.290     98.12           81.77    0.534
# 4209           115.9         0.290     98.12           81.77    0.534
#
#       POSS_OPP  REB_PCT_OPP  TM_TOV_PCT_OPP  TS_PCT_OPP  \
# 0         4452        0.520           0.200       0.541
# 1         4452        0.520           0.200       0.541
# 2         4452        0.520           0.200       0.541
# 3         4452        0.520           0.200       0.541
# 4         4452        0.520           0.200       0.541
# ...        ...          ...             ...         ...
# 4205      5694        0.522           0.145       0.592
# 4206      5694        0.522           0.145       0.592
# 4207      5694        0.522           0.145       0.592
# 4208      5694        0.522           0.145       0.592
# 4209      5694        0.522           0.145       0.592
#
#       OPP_PTS_2ND_CHANCE_OPP  OPP_PTS_FB_OPP  OPP_PTS_OFF_TOV_OPP  \
# 0                       13.6             8.7                 20.4
# 1                       13.6             8.7                 20.4
# 2                       13.6             8.7                 20.4
# 3                       13.6             8.7                 20.4
# 4                       13.6             8.7                 20.4
# ...                      ...             ...                  ...
# 4205                    13.1            12.2                 17.0
# 4206                    13.1            12.2                 17.0
# 4207                    13.1            12.2                 17.0
# 4208                    13.1            12.2                 17.0
# 4209                    13.1            12.2                 17.0
#
#       OPP_PTS_PAINT_OPP  PTS_2ND_CHANCE_OPP  PTS_FB_OPP  PTS_OFF_TOV_OPP  \
# 0                  35.3                15.3        12.6             20.7
# 1                  35.3                15.3        12.6             20.7
# 2                  35.3                15.3        12.6             20.7
# 3                  35.3                15.3        12.6             20.7
# 4                  35.3                15.3        12.6             20.7
# ...                 ...                 ...         ...              ...
# 4205               47.2                14.6        10.1             15.2
# 4206               47.2                14.6        10.1             15.2
# 4207               47.2                14.6        10.1             15.2
# 4208               47.2                14.6        10.1             15.2
# 4209               47.2                14.6        10.1             15.2
#
#       PTS_PAINT_OPP  FTA_RATE_OPP  OPP_EFG_PCT_OPP  OPP_FTA_RATE_OPP  \
# 0              42.3         0.318            0.466             0.389
# 1              42.3         0.318            0.466             0.389
# 2              42.3         0.318            0.466             0.389
# 3              42.3         0.318            0.466             0.389
# 4              42.3         0.318            0.466             0.389
# ...             ...           ...              ...               ...
# 4205           49.1         0.265            0.516             0.209
# 4206           49.1         0.265            0.516             0.209
# 4207           49.1         0.265            0.516             0.209
# 4208           49.1         0.265            0.516             0.209
# 4209           49.1         0.265            0.516             0.209
#
#       OPP_OREB_PCT_OPP  OPP_TOV_PCT_OPP  PCT_AST_2PM_OPP  PCT_AST_3PM_OPP  \
# 0                0.303            0.190            0.593            0.773
# 1                0.303            0.190            0.593            0.773
# 2                0.303            0.190            0.593            0.773
# 3                0.303            0.190            0.593            0.773
# 4                0.303            0.190            0.593            0.773
# ...                ...              ...              ...              ...
# 4205             0.264            0.124            0.452            0.722
# 4206             0.264            0.124            0.452            0.722
# 4207             0.264            0.124            0.452            0.722
# 4208             0.264            0.124            0.452            0.722
# 4209             0.264            0.124            0.452            0.722
#
#       PCT_AST_FGM_OPP  PCT_FGA_2PT_OPP  PCT_FGA_3PT_OPP  PCT_PTS_2PT_OPP  \
# 0               0.622            0.795            0.205            0.623
# 1               0.622            0.795            0.205            0.623
# 2               0.622            0.795            0.205            0.623
# 3               0.622            0.795            0.205            0.623
# 4               0.622            0.795            0.205            0.623
# ...               ...              ...              ...              ...
# 4205            0.549            0.532            0.468            0.460
# 4206            0.549            0.532            0.468            0.460
# 4207            0.549            0.532            0.468            0.460
# 4208            0.549            0.532            0.468            0.460
# 4209            0.549            0.532            0.468            0.460
#
#       PCT_PTS_2PT_MR_OPP  PCT_PTS_3PT_OPP  PCT_PTS_FB_OPP  PCT_PTS_FT_OPP  \
# 0                  0.209            0.183           0.123           0.193
# 1                  0.209            0.183           0.123           0.193
# 2                  0.209            0.183           0.123           0.193
# 3                  0.209            0.183           0.123           0.193
# 4                  0.209            0.183           0.123           0.193
# ...                  ...              ...             ...             ...
# 4205               0.036            0.383           0.087           0.157
# 4206               0.036            0.383           0.087           0.157
# 4207               0.036            0.383           0.087           0.157
# 4208               0.036            0.383           0.087           0.157
# 4209               0.036            0.383           0.087           0.157
#
#       PCT_PTS_OFF_TOV_OPP  PCT_PTS_PAINT_OPP  PCT_UAST_2PM_OPP  \
# 0                   0.202              0.414             0.407
# 1                   0.202              0.414             0.407
# 2                   0.202              0.414             0.407
# 3                   0.202              0.414             0.407
# 4                   0.202              0.414             0.407
# ...                   ...                ...               ...
# 4205                0.131              0.424             0.548
# 4206                0.131              0.424             0.548
# 4207                0.131              0.424             0.548
# 4208                0.131              0.424             0.548
# 4209                0.131              0.424             0.548
#
#       PCT_UAST_3PM_OPP  PCT_UAST_FGM_OPP  OPP_AST_OPP  OPP_BLK_OPP  \
# 0                0.227             0.378         20.9          3.9
# 1                0.227             0.378         20.9          3.9
# 2                0.227             0.378         20.9          3.9
# 3                0.227             0.378         20.9          3.9
# 4                0.227             0.378         20.9          3.9
# ...                ...               ...          ...          ...
# 4205             0.278             0.451         23.5          4.3
# 4206             0.278             0.451         23.5          4.3
# 4207             0.278             0.451         23.5          4.3
# 4208             0.278             0.451         23.5          4.3
# 4209             0.278             0.451         23.5          4.3
#
#       OPP_BLKA_OPP  OPP_DREB_OPP  OPP_FG3A_OPP  OPP_FG3M_OPP  OPP_FG3_PCT_OPP  \
# 0              5.4          29.3          18.4           6.6            0.360
# 1              5.4          29.3          18.4           6.6            0.360
# 2              5.4          29.3          18.4           6.6            0.360
# 3              5.4          29.3          18.4           6.6            0.360
# 4              5.4          29.3          18.4           6.6            0.360
# ...            ...           ...           ...           ...              ...
# 4205           5.0          32.5          35.0          12.0            0.342
# 4206           5.0          32.5          35.0          12.0            0.342
# 4207           5.0          32.5          35.0          12.0            0.342
# 4208           5.0          32.5          35.0          12.0            0.342
# 4209           5.0          32.5          35.0          12.0            0.342
#
#       OPP_FGA_OPP  OPP_FGM_OPP  OPP_FG_PCT_OPP  OPP_FTA_OPP  OPP_FTM_OPP  \
# 0            81.0         34.4           0.425         31.5         22.9
# 1            81.0         34.4           0.425         31.5         22.9
# 2            81.0         34.4           0.425         31.5         22.9
# 3            81.0         34.4           0.425         31.5         22.9
# 4            81.0         34.4           0.425         31.5         22.9
# ...           ...          ...             ...          ...          ...
# 4205         91.7         41.3           0.450         19.2         14.3
# 4206         91.7         41.3           0.450         19.2         14.3
# 4207         91.7         41.3           0.450         19.2         14.3
# 4208         91.7         41.3           0.450         19.2         14.3
# 4209         91.7         41.3           0.450         19.2         14.3
#
#       OPP_FT_PCT_OPP  OPP_OREB_OPP  OPP_PF_OPP  OPP_PFD_OPP  OPP_PTS_OPP  \
# 0              0.726          11.7        24.2         26.9         98.3
# 1              0.726          11.7        24.2         26.9         98.3
# 2              0.726          11.7        24.2         26.9         98.3
# 3              0.726          11.7        24.2         26.9         98.3
# 4              0.726          11.7        24.2         26.9         98.3
# ...              ...           ...         ...          ...          ...
# 4205           0.746          10.3        20.4         19.3        108.9
# 4206           0.746          10.3        20.4         19.3        108.9
# 4207           0.746          10.3        20.4         19.3        108.9
# 4208           0.746          10.3        20.4         19.3        108.9
# 4209           0.746          10.3        20.4         19.3        108.9
#
#       OPP_REB_OPP  OPP_STL_OPP  OPP_TOV_OPP
# 0            41.0          9.9         19.0
# 1            41.0          9.9         19.0
# 2            41.0          9.9         19.0
# 3            41.0          9.9         19.0
# 4            41.0          9.9         19.0
# ...           ...          ...          ...
# 4205         42.8          7.7         12.4
# 4206         42.8          7.7         12.4
# 4207         42.8          7.7         12.4
# 4208         42.8          7.7         12.4
# 4209         42.8          7.7         12.4
#
# [4210 rows x 195 columns]

# %%
pd.DataFrame(df.dtypes).T
# Out:
#   GAME_ID TEAM_ID TEAM_ID_OPP GAME_DATE MATCHUP OUTCOME   HOME  SEASON  \
# 0   int64   int64       int64    object  object   int64  int64  object
#
#   TEAM_NAME     GP      W      L    W_PCT      MIN      FGM      FGA   FG_PCT  \
# 0    object  int64  int64  int64  float64  float64  float64  float64  float64
#
#       FG3M     FG3A  FG3_PCT      FTM      FTA   FT_PCT     OREB     DREB  \
# 0  float64  float64  float64  float64  float64  float64  float64  float64
#
#        REB      AST      TOV      STL      BLK     BLKA       PF      PFD  \
# 0  float64  float64  float64  float64  float64  float64  float64  float64
#
#        PTS PLUS_MINUS   CFID CFPARAMS  AST_PCT AST_RATIO   AST_TO DEF_RATING  \
# 0  float64    float64  int64   object  float64   float64  float64    float64
#
#   DREB_PCT  EFG_PCT NET_RATING OFF_RATING OREB_PCT     PACE PACE_PER40  \
# 0  float64  float64    float64    float64  float64  float64    float64
#
#        PIE   POSS  REB_PCT TM_TOV_PCT   TS_PCT OPP_PTS_2ND_CHANCE OPP_PTS_FB  \
# 0  float64  int64  float64    float64  float64            float64    float64
#
#   OPP_PTS_OFF_TOV OPP_PTS_PAINT PTS_2ND_CHANCE   PTS_FB PTS_OFF_TOV PTS_PAINT  \
# 0         float64       float64        float64  float64     float64   float64
#
#   FTA_RATE OPP_EFG_PCT OPP_FTA_RATE OPP_OREB_PCT OPP_TOV_PCT PCT_AST_2PM  \
# 0  float64     float64      float64      float64     float64     float64
#
#   PCT_AST_3PM PCT_AST_FGM PCT_FGA_2PT PCT_FGA_3PT PCT_PTS_2PT PCT_PTS_2PT_MR  \
# 0     float64     float64     float64     float64     float64        float64
#
#   PCT_PTS_3PT PCT_PTS_FB PCT_PTS_FT PCT_PTS_OFF_TOV PCT_PTS_PAINT  \
# 0     float64    float64    float64         float64       float64
#
#   PCT_UAST_2PM PCT_UAST_3PM PCT_UAST_FGM  OPP_AST  OPP_BLK OPP_BLKA OPP_DREB  \
# 0      float64      float64      float64  float64  float64  float64  float64
#
#   OPP_FG3A OPP_FG3M OPP_FG3_PCT  OPP_FGA  OPP_FGM OPP_FG_PCT  OPP_FTA  \
# 0  float64  float64     float64  float64  float64    float64  float64
#
#    OPP_FTM OPP_FT_PCT OPP_OREB   OPP_PF  OPP_PFD  OPP_PTS  OPP_REB  OPP_STL  \
# 0  float64    float64  float64  float64  float64  float64  float64  float64
#
#    OPP_TOV TEAM_ID_OPP.1 TEAM_NAME_OPP GP_OPP  W_OPP  L_OPP W_PCT_OPP  \
# 0  float64         int64        object  int64  int64  int64   float64
#
#    MIN_OPP  FGM_OPP  FGA_OPP FG_PCT_OPP FG3M_OPP FG3A_OPP FG3_PCT_OPP  \
# 0  float64  float64  float64    float64  float64  float64     float64
#
#    FTM_OPP  FTA_OPP FT_PCT_OPP OREB_OPP DREB_OPP  REB_OPP  AST_OPP  TOV_OPP  \
# 0  float64  float64    float64  float64  float64  float64  float64  float64
#
#    STL_OPP  BLK_OPP BLKA_OPP   PF_OPP  PFD_OPP  PTS_OPP PLUS_MINUS_OPP  \
# 0  float64  float64  float64  float64  float64  float64        float64
#
#   CFID_OPP CFPARAMS_OPP AST_PCT_OPP AST_RATIO_OPP AST_TO_OPP DEF_RATING_OPP  \
# 0    int64       object     float64       float64    float64        float64
#
#   DREB_PCT_OPP EFG_PCT_OPP NET_RATING_OPP OFF_RATING_OPP OREB_PCT_OPP  \
# 0      float64     float64        float64        float64      float64
#
#   PACE_OPP PACE_PER40_OPP  PIE_OPP POSS_OPP REB_PCT_OPP TM_TOV_PCT_OPP  \
# 0  float64        float64  float64    int64     float64        float64
#
#   TS_PCT_OPP OPP_PTS_2ND_CHANCE_OPP OPP_PTS_FB_OPP OPP_PTS_OFF_TOV_OPP  \
# 0    float64                float64        float64             float64
#
#   OPP_PTS_PAINT_OPP PTS_2ND_CHANCE_OPP PTS_FB_OPP PTS_OFF_TOV_OPP  \
# 0           float64            float64    float64         float64
#
#   PTS_PAINT_OPP FTA_RATE_OPP OPP_EFG_PCT_OPP OPP_FTA_RATE_OPP  \
# 0       float64      float64         float64          float64
#
#   OPP_OREB_PCT_OPP OPP_TOV_PCT_OPP PCT_AST_2PM_OPP PCT_AST_3PM_OPP  \
# 0          float64         float64         float64         float64
#
#   PCT_AST_FGM_OPP PCT_FGA_2PT_OPP PCT_FGA_3PT_OPP PCT_PTS_2PT_OPP  \
# 0         float64         float64         float64         float64
#
#   PCT_PTS_2PT_MR_OPP PCT_PTS_3PT_OPP PCT_PTS_FB_OPP PCT_PTS_FT_OPP  \
# 0            float64         float64        float64        float64
#
#   PCT_PTS_OFF_TOV_OPP PCT_PTS_PAINT_OPP PCT_UAST_2PM_OPP PCT_UAST_3PM_OPP  \
# 0             float64           float64          float64          float64
#
#   PCT_UAST_FGM_OPP OPP_AST_OPP OPP_BLK_OPP OPP_BLKA_OPP OPP_DREB_OPP  \
# 0          float64     float64     float64      float64      float64
#
#   OPP_FG3A_OPP OPP_FG3M_OPP OPP_FG3_PCT_OPP OPP_FGA_OPP OPP_FGM_OPP  \
# 0      float64      float64         float64     float64     float64
#
#   OPP_FG_PCT_OPP OPP_FTA_OPP OPP_FTM_OPP OPP_FT_PCT_OPP OPP_OREB_OPP  \
# 0        float64     float64     float64        float64      float64
#
#   OPP_PF_OPP OPP_PFD_OPP OPP_PTS_OPP OPP_REB_OPP OPP_STL_OPP OPP_TOV_OPP
# 0    float64     float64     float64     float64     float64     float64

# %%
df.describe()
# Out:
#             GAME_ID       TEAM_ID   TEAM_ID_OPP      OUTCOME         HOME  \
# count  4.210000e+03  4.210000e+03  4.210000e+03  4210.000000  4210.000000
# mean   4.223452e+07  1.610613e+09  1.610613e+09     0.500000     0.500000
# std    3.026020e+06  8.453985e+00  8.453985e+00     0.500059     0.500059
# min    4.000000e+07  1.610613e+09  1.610613e+09     0.000000     0.000000
# 25%    4.060020e+07  1.610613e+09  1.610613e+09     0.000000     0.000000
# 50%    4.120030e+07  1.610613e+09  1.610613e+09     0.500000     0.500000
# 75%    4.190012e+07  1.610613e+09  1.610613e+09     1.000000     1.000000
# max    4.990009e+07  1.610613e+09  1.610613e+09     1.000000     1.000000
#
#                 GP            W            L        W_PCT          MIN  \
# count  4210.000000  4210.000000  4210.000000  4210.000000  4210.000000
# mean     50.757720    32.769359    17.988361     0.644154    51.003444
# std      11.470218     9.305831     6.464488     0.104146     1.953282
# min       4.000000     2.000000     0.000000     0.354000    45.500000
# 25%      49.000000    28.000000    14.000000     0.571000    49.700000
# 50%      52.000000    33.000000    18.000000     0.646500    51.200000
# 75%      55.000000    38.000000    22.000000     0.719000    52.500000
# max      82.000000    62.000000    41.000000     1.000000    56.000000
#
#                FGM          FGA       FG_PCT        FG3M         FG3A  \
# count  4210.000000  4210.000000  4210.000000  4210.00000  4210.000000
# mean     39.760333    86.423444     0.460159     8.13133    22.363777
# std       1.699563     2.449191     0.017884     2.97398     7.766788
# min      33.500000    78.700000     0.402000     1.50000     5.100000
# 25%      38.700000    84.600000     0.448000     6.00000    16.700000
# 50%      39.900000    86.600000     0.460000     7.60000    20.800000
# 75%      40.900000    88.100000     0.472000    10.30000    27.600000
# max      43.700000    93.400000     0.510000    17.10000    45.300000
#
#           FG3_PCT          FTM          FTA       FT_PCT        OREB  \
# count  4210.00000  4210.000000  4210.000000  4210.000000  4210.00000
# mean      0.36128    19.634537    25.901378     0.760010    11.61190
# std       0.02360     2.474898     3.547873     0.037476     1.79637
# min       0.26700    10.600000    18.500000     0.560000     7.60000
# 25%       0.34700    17.900000    23.000000     0.741000    10.40000
# 50%       0.36200    19.600000    25.700000     0.761000    11.40000
# 75%       0.37800    21.200000    28.200000     0.784000    12.90000
# max       0.42400    30.200000    38.900000     0.844000    17.40000
#
#               DREB          REB          AST          TOV          STL  \
# 50%       0.595000      17.200000     1.580000      102.900000      0.704000
# 75%       0.629000      18.100000     1.720000      105.900000      0.719000
# max       0.719000      21.500000     2.140000      115.700000      0.772000
#
#        EFG_PCT_OPP  NET_RATING_OPP  OFF_RATING_OPP  OREB_PCT_OPP     PACE_OPP  \
# count  4210.000000     4210.000000     4210.000000   4210.000000  4210.000000
# mean      0.507138        4.385083      107.286675      0.297480    94.229686
# std       0.028326        3.368993        4.477780      0.030378     3.664983
# min       0.418000       -4.300000       93.600000      0.231000    85.660000
# 25%       0.487000        2.000000      104.000000      0.276000    91.420000
# 50%       0.507000        4.100000      107.700000      0.297000    93.670000
# 75%       0.526000        6.800000      110.700000      0.321000    96.660000
# max       0.588000       13.800000      118.200000      0.383000   105.430000
#
#        PACE_PER40_OPP      PIE_OPP     POSS_OPP  REB_PCT_OPP  TM_TOV_PCT_OPP  \
# count     4210.000000  4210.000000  4210.000000  4210.000000     4210.000000
# mean        78.524473     0.531208  4823.802613     0.504697        0.151901
# std          3.053941     0.026191  1104.224274     0.013143        0.014074
# min         71.380000     0.467000   361.000000     0.447000        0.115000
# 25%         76.190000     0.514000  4579.000000     0.496000        0.142000
# 50%         78.060000     0.530000  4881.000000     0.506000        0.151000
# 75%         80.550000     0.550000  5303.000000     0.514000        0.161000
# max         87.860000     0.645000  7836.000000     0.535000        0.200000
#
#         TS_PCT_OPP  OPP_PTS_2ND_CHANCE_OPP  OPP_PTS_FB_OPP  \
# count  4210.000000             4210.000000     4210.000000
# mean      0.548613               13.841568       12.761283
# std       0.025224                1.341039        1.684485
# min       0.456000               10.700000        6.200000
# 25%       0.531000               13.000000       11.700000
# 50%       0.549000               13.700000       12.700000
# 75%       0.567000               14.800000       13.800000
# max       0.621000               19.700000       19.700000
#
#        OPP_PTS_OFF_TOV_OPP  OPP_PTS_PAINT_OPP  PTS_2ND_CHANCE_OPP  \
# count          4210.000000        4210.000000         4210.000000
# mean             16.620926          42.068314           13.828717
# std               1.453686           3.741563            1.741823
# min               9.700000          29.900000            9.700000
# 25%              15.700000          39.700000           12.600000
# 50%              16.600000          42.200000           13.750000
# 75%              17.400000          44.500000           15.000000
# max              21.500000          53.700000           20.400000
#
#         PTS_FB_OPP  PTS_OFF_TOV_OPP  PTS_PAINT_OPP  FTA_RATE_OPP  \
# count  4210.000000      4210.000000    4210.000000   4210.000000
# mean     13.791164        17.705178      43.602684      0.300631
# std       2.885571         1.725267       4.117661      0.047155
# min       6.900000        13.100000      32.200000      0.205000
# 25%      11.700000        16.600000      40.900000      0.264000
# 50%      13.400000        17.700000      44.000000      0.296000
# 75%      15.600000        18.800000      46.200000      0.329000
# max      22.800000        24.900000      58.700000      0.494000
#
#        OPP_EFG_PCT_OPP  OPP_FTA_RATE_OPP  OPP_OREB_PCT_OPP  OPP_TOV_PCT_OPP  \
# count      4210.000000       4210.000000       4210.000000      4210.000000
# mean          0.483421          0.286906          0.295994         0.155593
# std           0.026595          0.040704          0.025086         0.015310
# min           0.385000          0.204000          0.228000         0.116000
# 25%           0.466000          0.256000          0.281000         0.145000
# mean          0.344644    86.997007    38.367387        0.441018    24.894941
# std           0.021715     2.161733     1.730118        0.016449     3.066230
# min           0.159000    79.200000    30.300000        0.368000    18.400000
# 25%           0.335000    85.600000    37.300000        0.430000    22.500000
# 50%           0.345000    87.200000    38.400000        0.442000    24.600000
# 75%           0.358000    88.400000    39.600000        0.453000    26.875000
# max           0.409000    93.300000    42.400000        0.478000    34.700000
#
#        OPP_FTM_OPP  OPP_FT_PCT_OPP  OPP_OREB_OPP   OPP_PF_OPP  OPP_PFD_OPP  \
# count  4210.000000     4210.000000   4210.000000  4210.000000  4210.000000
# mean     18.728195        0.753144     11.839929    22.695606    22.121069
# std       2.191747        0.021692      1.568579     2.443643     2.278017
# min      14.300000        0.595000      8.100000    17.500000    17.600000
# 25%      17.100000        0.742000     10.700000    20.800000    20.500000
# 50%      18.500000        0.753000     11.800000    22.600000    21.900000
# 75%      20.200000        0.766000     12.800000    24.400000    23.400000
# max      26.700000        0.824000     18.000000    32.400000    31.000000
#
#        OPP_PTS_OPP  OPP_REB_OPP  OPP_STL_OPP  OPP_TOV_OPP
# count  4210.000000  4210.000000  4210.000000  4210.000000
# mean    102.854988    44.312755     7.912803    15.554109
# std       4.342939     1.748878     0.794819     1.532343
# min      86.000000    39.700000     5.500000    11.600000
# 25%     100.000000    43.100000     7.400000    14.500000
# 50%     102.800000    44.200000     7.900000    15.500000
# 75%     105.800000    45.400000     8.400000    16.600000
# max     115.800000    49.700000    12.100000    21.700000

# %% [markdown]
# # Remove outlier rows by GP

# %%
# consider removing outlier in terms of games played 
# since those records are not representative samples of mid-season performance
# 1997-98: 82 games played = whole season but not mid-season, 
  # all-star game was held in Feb (Kobe's debut for youngest all-star player)
  # season lasted from Oct to Apr
# 1998-89: see 1998 NBA lockout
  # < 10 games played = too small of a sample size to gauge mid-season performance
# 2011-12: see 2011 NBA lockout
# 2020-21: see postponed season due to COVID-19
df.groupby('SEASON').GP.mean().plot(kind='bar')
plt.axhline(30)
plt.axhline(60)

# %%
# cannot pass this in sklearn pipeline so let's do it on dataset level
# drop any season with games played <= 30 or >= 60 such that we have a large enough sample to gauge mid-season performance
df = df.loc[(df.GP >= 30) & (df.GP <= 60)]

# %%
# now fixed
df.groupby('SEASON').GP.mean().plot(kind='bar')
plt.axhline(30)
plt.axhline(60)

# %%
# fix datatypes
df.loc[:, 'GAME_ID'] = df['GAME_ID'].astype(str)
df.loc[:, 'TEAM_ID'] = df['TEAM_ID'].astype(str)
df.loc[:, 'TEAM_ID_OPP'] = df['TEAM_ID_OPP'].astype(str)
df.loc[:, 'GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
df.loc[:, 'MATCHUP'] = df['MATCHUP'].astype(str)
df.loc[:, 'CFID'] = df['CFID'].astype(str)
df.loc[:, 'CFID_OPP'] = df['CFID_OPP'].astype(str)
df.loc[:, 'SEASON'] = df['SEASON'].astype('category')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
pd.DataFrame(df.select_dtypes(include=np.number).dtypes).T
# Out:
#   OUTCOME   HOME     GP      W      L    W_PCT      MIN      FGM      FGA  \
# 0   int64  int64  int64  int64  int64  float64  float64  float64  float64
#
#     FG_PCT     FG3M     FG3A  FG3_PCT      FTM      FTA   FT_PCT     OREB  \
# 0  float64  float64  float64  float64  float64  float64  float64  float64
#
#       DREB      REB      AST      TOV      STL      BLK     BLKA       PF  \
# 0  float64  float64  float64  float64  float64  float64  float64  float64
#
#        PFD      PTS PLUS_MINUS  AST_PCT AST_RATIO   AST_TO DEF_RATING  \
# 0  float64  float64    float64  float64   float64  float64    float64
#
#   DREB_PCT  EFG_PCT NET_RATING OFF_RATING OREB_PCT     PACE PACE_PER40  \
# 0  float64  float64    float64    float64  float64  float64    float64
#
#        PIE   POSS  REB_PCT TM_TOV_PCT   TS_PCT OPP_PTS_2ND_CHANCE OPP_PTS_FB  \
# 0  float64  int64  float64    float64  float64            float64    float64
#
#   OPP_PTS_OFF_TOV OPP_PTS_PAINT PTS_2ND_CHANCE   PTS_FB PTS_OFF_TOV PTS_PAINT  \
# 0         float64       float64        float64  float64     float64   float64
#
#   FTA_RATE OPP_EFG_PCT OPP_FTA_RATE OPP_OREB_PCT OPP_TOV_PCT PCT_AST_2PM  \
# 0  float64     float64      float64      float64     float64     float64
#
#   PCT_AST_3PM PCT_AST_FGM PCT_FGA_2PT PCT_FGA_3PT PCT_PTS_2PT PCT_PTS_2PT_MR  \
# 0     float64     float64     float64     float64     float64        float64
#
#   PCT_PTS_3PT PCT_PTS_FB PCT_PTS_FT PCT_PTS_OFF_TOV PCT_PTS_PAINT  \
# 0     float64    float64    float64         float64       float64
#
#   PCT_UAST_2PM PCT_UAST_3PM PCT_UAST_FGM  OPP_AST  OPP_BLK OPP_BLKA OPP_DREB  \
# 0      float64      float64      float64  float64  float64  float64  float64
#
#   OPP_FG3A OPP_FG3M OPP_FG3_PCT  OPP_FGA  OPP_FGM OPP_FG_PCT  OPP_FTA  \
# 0  float64  float64     float64  float64  float64    float64  float64
#
#    OPP_FTM OPP_FT_PCT OPP_OREB   OPP_PF  OPP_PFD  OPP_PTS  OPP_REB  OPP_STL  \
# 0  float64    float64  float64  float64  float64  float64  float64  float64
#
#    OPP_TOV GP_OPP  W_OPP  L_OPP W_PCT_OPP  MIN_OPP  FGM_OPP  FGA_OPP  \
# 0  float64  int64  int64  int64   float64  float64  float64  float64
#
#   FG_PCT_OPP FG3M_OPP FG3A_OPP FG3_PCT_OPP  FTM_OPP  FTA_OPP FT_PCT_OPP  \
# 0    float64  float64  float64     float64  float64  float64    float64
#
#   OREB_OPP DREB_OPP  REB_OPP  AST_OPP  TOV_OPP  STL_OPP  BLK_OPP BLKA_OPP  \
# 0  float64  float64  float64  float64  float64  float64  float64  float64
#
#     PF_OPP  PFD_OPP  PTS_OPP PLUS_MINUS_OPP AST_PCT_OPP AST_RATIO_OPP  \
# 0  float64  float64  float64        float64     float64       float64
#
#   AST_TO_OPP DEF_RATING_OPP DREB_PCT_OPP EFG_PCT_OPP NET_RATING_OPP  \
# 0    float64        float64      float64     float64        float64
#
#   OFF_RATING_OPP OREB_PCT_OPP PACE_OPP PACE_PER40_OPP  PIE_OPP POSS_OPP  \
# 0        float64      float64  float64        float64  float64    int64
#
#   REB_PCT_OPP TM_TOV_PCT_OPP TS_PCT_OPP OPP_PTS_2ND_CHANCE_OPP OPP_PTS_FB_OPP  \
# 0     float64        float64    float64                float64        float64
#
#   OPP_PTS_OFF_TOV_OPP OPP_PTS_PAINT_OPP PTS_2ND_CHANCE_OPP PTS_FB_OPP  \
# 0             float64           float64            float64    float64
#
#   PTS_OFF_TOV_OPP PTS_PAINT_OPP FTA_RATE_OPP OPP_EFG_PCT_OPP OPP_FTA_RATE_OPP  \
# 0         float64       float64      float64         float64          float64
#
#   OPP_OREB_PCT_OPP OPP_TOV_PCT_OPP PCT_AST_2PM_OPP PCT_AST_3PM_OPP  \
# 0          float64         float64         float64         float64
#
#   PCT_AST_FGM_OPP PCT_FGA_2PT_OPP PCT_FGA_3PT_OPP PCT_PTS_2PT_OPP  \
# 0         float64         float64         float64         float64
#
#   PCT_PTS_2PT_MR_OPP PCT_PTS_3PT_OPP PCT_PTS_FB_OPP PCT_PTS_FT_OPP  \
# 0            float64         float64        float64        float64
#
#   PCT_PTS_OFF_TOV_OPP PCT_PTS_PAINT_OPP PCT_UAST_2PM_OPP PCT_UAST_3PM_OPP  \
# 0             float64           float64          float64          float64
#
#   PCT_UAST_FGM_OPP OPP_AST_OPP OPP_BLK_OPP OPP_BLKA_OPP OPP_DREB_OPP  \
# 0          float64     float64     float64      float64      float64
#
#   OPP_FG3A_OPP OPP_FG3M_OPP OPP_FG3_PCT_OPP OPP_FGA_OPP OPP_FGM_OPP  \
# 0      float64      float64         float64     float64     float64
#
#   OPP_FG_PCT_OPP OPP_FTA_OPP OPP_FTM_OPP OPP_FT_PCT_OPP OPP_OREB_OPP  \
# 0        float64     float64     float64        float64      float64
#
#   OPP_PF_OPP OPP_PFD_OPP OPP_PTS_OPP OPP_REB_OPP OPP_STL_OPP OPP_TOV_OPP
# 0    float64     float64     float64     float64     float64     float64

# %%
pd.DataFrame(df.select_dtypes(exclude=np.number).dtypes).T
# Out:
#   GAME_ID TEAM_ID TEAM_ID_OPP       GAME_DATE MATCHUP    SEASON TEAM_NAME  \
# 0  object  object      object  datetime64[ns]  object  category    object
#
#      CFID CFPARAMS TEAM_NAME_OPP CFID_OPP CFPARAMS_OPP
# 0  object   object        object   object       object

# %% [markdown]
# # Check numeric columns

# %%
# no identifier included here
sorted(df.select_dtypes(include=np.number).columns.values)
# Out:
# ['AST',
#  'AST_OPP',
#  'AST_PCT',
#  'AST_PCT_OPP',
#  'AST_RATIO',
#  'AST_RATIO_OPP',
#  'AST_TO',
#  'AST_TO_OPP',
#  'BLK',
#  'BLKA',
#  'BLKA_OPP',
#  'BLK_OPP',
#  'DEF_RATING',
#  'DEF_RATING_OPP',
#  'DREB',
#  'DREB_OPP',
#  'DREB_PCT',
#  'DREB_PCT_OPP',
#  'EFG_PCT',
#  'EFG_PCT_OPP',
#  'FG3A',
#  'FG3A_OPP',
#  'FG3M',
#  'FG3M_OPP',
#  'FG3_PCT',
#  'FG3_PCT_OPP',
#  'FGA',
#  'FGA_OPP',
#  'FGM',
#  'FGM_OPP',
#  'FG_PCT',
#  'FG_PCT_OPP',
#  'FTA',
#  'FTA_OPP',
#  'FTA_RATE',
#  'FTA_RATE_OPP',
#  'FTM',
#  'FTM_OPP',
#  'FT_PCT',
#  'FT_PCT_OPP',
#  'GP',
#  'GP_OPP',
#  'HOME',
#  'L',
#  'L_OPP',
#  'MIN',
#  'MIN_OPP',
#  'NET_RATING',
#  'NET_RATING_OPP',
#  'OFF_RATING',
#  'OFF_RATING_OPP',
#  'OPP_AST',
#  'OPP_AST_OPP',
#  'OPP_BLK',
#  'OPP_BLKA',
#  'OPP_BLKA_OPP',
#  'OPP_BLK_OPP',
#  'OPP_DREB',
#  'OPP_DREB_OPP',
#  'OPP_EFG_PCT',
#  'OPP_EFG_PCT_OPP',
#  'OPP_FG3A',
#  'OPP_FG3A_OPP',
#  'OPP_FG3M',
#  'OPP_FG3M_OPP',
#  'OPP_FG3_PCT',
#  'OPP_FG3_PCT_OPP',
#  'OPP_FGA',
#  'OPP_FGA_OPP',
#  'OPP_FGM',
#  'OPP_FGM_OPP',
#  'OPP_FG_PCT',
#  'OPP_FG_PCT_OPP',
#  'OPP_FTA',
#  'OPP_FTA_OPP',
#  'OPP_FTA_RATE',
#  'OPP_FTA_RATE_OPP',
#  'OPP_FTM',
#  'OPP_FTM_OPP',
#  'OPP_FT_PCT',
#  'OPP_FT_PCT_OPP',
#  'OPP_OREB',
#  'OPP_OREB_OPP',
#  'OPP_OREB_PCT',
#  'OPP_OREB_PCT_OPP',
#  'OPP_PF',
#  'OPP_PFD',
#  'OPP_PFD_OPP',
#  'OPP_PF_OPP',
#  'OPP_PTS',
#  'OPP_PTS_2ND_CHANCE',
#  'OPP_PTS_2ND_CHANCE_OPP',
#  'OPP_PTS_FB',
#  'OPP_PTS_FB_OPP',
#  'OPP_PTS_OFF_TOV',
#  'OPP_PTS_OFF_TOV_OPP',
#  'OPP_PTS_OPP',
#  'OPP_PTS_PAINT',
#  'OPP_PTS_PAINT_OPP',
#  'OPP_REB',
#  'OPP_REB_OPP',
#  'OPP_STL',
#  'OPP_STL_OPP',
#  'OPP_TOV',
#  'OPP_TOV_OPP',
#  'OPP_TOV_PCT',
#  'OPP_TOV_PCT_OPP',
#  'OREB',
#  'OREB_OPP',
#  'OREB_PCT',
#  'OREB_PCT_OPP',
#  'OUTCOME',
#  'PACE',
#  'PACE_OPP',
#  'PACE_PER40',
#  'PACE_PER40_OPP',
#  'PCT_AST_2PM',
#  'PCT_AST_2PM_OPP',
#  'PCT_AST_3PM',
#  'PCT_AST_3PM_OPP',
#  'PCT_AST_FGM',
#  'PCT_AST_FGM_OPP',
#  'PCT_FGA_2PT',
#  'PCT_FGA_2PT_OPP',
#  'PCT_FGA_3PT',
#  'PCT_FGA_3PT_OPP',
#  'PCT_PTS_2PT',
#  'PCT_PTS_2PT_MR',
#  'PCT_PTS_2PT_MR_OPP',
#  'PCT_PTS_2PT_OPP',
#  'PCT_PTS_3PT',
#  'PCT_PTS_3PT_OPP',
#  'PCT_PTS_FB',
#  'PCT_PTS_FB_OPP',
#  'PCT_PTS_FT',
#  'PCT_PTS_FT_OPP',
#  'PCT_PTS_OFF_TOV',
#  'PCT_PTS_OFF_TOV_OPP',
#  'PCT_PTS_PAINT',
#  'PCT_PTS_PAINT_OPP',
#  'PCT_UAST_2PM',
#  'PCT_UAST_2PM_OPP',
#  'PCT_UAST_3PM',
#  'PCT_UAST_3PM_OPP',
#  'PCT_UAST_FGM',
#  'PCT_UAST_FGM_OPP',
#  'PF',
#  'PFD',
#  'PFD_OPP',
#  'PF_OPP',
#  'PIE',
#  'PIE_OPP',
#  'PLUS_MINUS',
#  'PLUS_MINUS_OPP',
#  'POSS',
#  'POSS_OPP',
#  'PTS',
#  'PTS_2ND_CHANCE',
#  'PTS_2ND_CHANCE_OPP',
#  'PTS_FB',
#  'PTS_FB_OPP',
#  'PTS_OFF_TOV',
#  'PTS_OFF_TOV_OPP',
#  'PTS_OPP',
#  'PTS_PAINT',
#  'PTS_PAINT_OPP',
#  'REB',
#  'REB_OPP',
#  'REB_PCT',
#  'REB_PCT_OPP',
#  'STL',
#  'STL_OPP',
#  'TM_TOV_PCT',
#  'TM_TOV_PCT_OPP',
#  'TOV',
#  'TOV_OPP',
#  'TS_PCT',
#  'TS_PCT_OPP',
#  'W',
#  'W_OPP',
#  'W_PCT',
#  'W_PCT_OPP']

# %% [markdown]
# # Train test split with unique identifier = GAME_ID + SEASON
# - hashing unique identifier
# - alternative: stratified sampling by season

# %%
# unique id = GAME id + season
df.loc[:, 'UNIQUE_ID'] = df['GAME_ID'].astype(str) + df['SEASON'].str.replace('-','')

# %%
# instead of train-test_split by random shuffling, hash the unique identifier for train-test split
# slight modification to the technique from Hands On Machine Learning by Aurélien Géron
def split_data_with_id_hash(data, test_ratio, id_column):
  ids = data[id_column]
  threshold = np.quantile(ids.apply(lambda x: crc32(np.int64(x))), test_ratio) # instead of using test_ratio * 2**32 as the threshold, this is more accurate
  in_test_set = ids.apply(lambda x: crc32(np.int64(x)) < threshold) 
  return data.loc[~in_test_set], data.loc[in_test_set]

# %%
train_set, test_set = split_data_with_id_hash(df, 0.2, "UNIQUE_ID")

# %%
print(f"size of full dataset: {df.shape}")
print(f"size of train dataset: {train_set.shape}")
print(f"size of test dataset: {test_set.shape}")
print(f"train-test ratio: {train_set.shape[0] / df.shape[0]:0.2} / {test_set.shape[0] / df.shape[0]:0.2}")
# Out:
# size of full dataset: (3931, 195)
# size of train dataset: (3145, 195)
# size of test dataset: (786, 195)
# train-test ratio: 0.8 / 0.2

# %%
# save to google drive
train_set.to_pickle('nba_pre_all_star_vs_playoff_games_train_comprehensive.pkl')
test_set.to_pickle('nba_pre_all_star_vs_playoff_games_test_comprehensive.pkl')

# download local copy to push to github
from google.colab import files
files.download("nba_pre_all_star_vs_playoff_games_train_comprehensive.pkl")
files.download("nba_pre_all_star_vs_playoff_games_test_comprehensive.pkl")
